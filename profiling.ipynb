# %%
from pyinstrument import Profiler
from titiler.eopf.reader import GeoZarrReader

# %% [markdown]
# # Dataset Open

# %%
profiler = Profiler()
with profiler:
    with GeoZarrReader(
        "s3://esa-zarr-sentinel-explorer-fra/tests-output/sentinel-2-l2a/S2C_MSIL2A_20260117T101351_N0511_R022_T32TQM_20260117T135312.zarr"
    ) as src:
        pass

profiler.print()
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 22:35:05  Samples:  207
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.762     CPU time: 0.274
# /   _/                      v5.1.2
#
# Profile at /tmp/ipykernel_1374257/1379267011.py:2
#
# 0.761 <module>  /tmp/ipykernel_1374257/1379267011.py:1
# └─ 0.761 GeoZarrReader.__init__  <attrs generated methods titiler.eopf.reader.GeoZarrReader>:37
#    └─ 0.761 GeoZarrReader.__attrs_post_init__  titiler/eopf/reader.py:516
#       ├─ 0.712 open_dataset  titiler/eopf/reader.py:77
#       │  ├─ 0.698 _open_dataset  titiler/eopf/reader.py:93
#       │  │  ├─ 0.668 open_datatree  xarray/backends/api.py:1004
#       │  │  │     [45 frames hidden]  xarray, zarr, concurrent, threading, ...
#       │  │  │        0.541 lock.acquire  <built-in>
#       │  │  └─ 0.023 Boto3CredentialProvider.__init__  obstore/auth/boto3.py:68
#       │  │        [6 frames hidden]  boto3, botocore
#       │  └─ 0.014 cache_settings  titiler/eopf/reader.py:67
# ...

# %% [markdown]
# # Dataset Info

# %%
profiler = Profiler()
with profiler:
    with GeoZarrReader(
        "s3://esa-zarr-sentinel-explorer-fra/tests-output/sentinel-2-l2a/S2C_MSIL2A_20260117T101351_N0511_R022_T32TQM_20260117T135312.zarr"
    ) as src:
        info = src.info()

profiler.print()
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 22:35:10  Samples:  69
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.069     CPU time: 0.072
# /   _/                      v5.1.2
#
# Profile at /tmp/ipykernel_1374257/491587051.py:2
#
# 0.068 <module>  /tmp/ipykernel_1374257/491587051.py:1
# ├─ 0.044 GeoZarrReader.__init__  <attrs generated methods titiler.eopf.reader.GeoZarrReader>:37
# │  └─ 0.044 GeoZarrReader.__attrs_post_init__  titiler/eopf/reader.py:516
# │     ├─ 0.038 GeoZarrReader._get_groups  titiler/eopf/reader.py:567
# │     │  ├─ 0.029 _validate_zarr  titiler/eopf/reader.py:203
# │     │  │  ├─ 0.028 RasterDataset.crs  rioxarray/raster_dataset.py:30
# │     │  │  │     [60 frames hidden]  rioxarray, xarray, contextlib, diffli...
# │     │  │  └─ 0.001 _CachedAccessor.__get__  xarray/core/extensions.py:21
# │     │  │        [4 frames hidden]  xarray
# │     │  ├─ 0.006 DataTree.__getitem__  xarray/core/datatree.py:922
# ...

# %% [markdown]
# ```
# 0.131 <module>  <ipython-input-2-0296d0b0414c>:1
# ├─ 0.108 GeoZarrReader.info  titiler/eopf/reader.py:1068
# │  └─ 0.108 _get_info_safe  titiler/eopf/reader.py:1081
# │     ├─ 0.052 GeoZarrReader._get_variable  titiler/eopf/reader.py:839
# │     │  ├─ 0.026 _arrange_dims  titiler/eopf/reader.py:223
# │     │  │  ├─ 0.018 RasterArray.write_crs  rioxarray/rioxarray.py:490
# │     │  │  │  ├─ 0.010 DataArrayCoordinates.__setitem__  xarray/core/coordinates.py:564
# │     │  │  │  │  └─ 0.010 DataArrayCoordinates.update  xarray/core/coordinates.py:567
# │     │  │  │  │     └─ 0.010 merge_coords  xarray/structure/merge.py:585
# │     │  │  │  │        └─ 0.008 deep_align  xarray/structure/alignment.py:972
# │     │  │  │  │           └─ 0.007 align  xarray/structure/alignment.py:764
# │     │  │  │  │              ├─ 0.005 Aligner.align  xarray/structure/alignment.py:651
# │     │  │  │  │              │  └─ 0.005 Aligner.reindex_all  xarray/structure/alignment.py:638
# │     │  │  │  │              │     └─ 0.005 Aligner._reindex_one  xarray/structure/alignment.py:617
# │     │  │  │  │              │        └─ 0.005 Coordinates._reindex_callback  xarray/core/coordinates.py:669
# │     │  │  │  │              │           ├─ 0.002 Dataset._reindex_callback  xarray/core/dataset.py:3333
# │     │  │  │  │              │           └─ 0.002 Coordinates.to_dataset  xarray/core/coordinates.py:453
# │     │  │  │  │              │              └─ 0.002 Dataset._copy_listed  xarray/core/dataset.py:1186
# │     │  │  │  │              └─ 0.002 Aligner.__init__  xarray/structure/alignment.py:180
# │     │  │  │  │                 └─ 0.002 _normalize_indexes  xarray/structure/alignment.py:99
# │     │  │  │  ├─ 0.002 CRS.to_cf  pyproj/crs/crs.py:620
# │     │  │  │  └─ 0.002 RasterArray._set_crs  rioxarray/rioxarray.py:397
# │     │  │  │     └─ 0.002 RasterArray._get_obj  rioxarray/rioxarray.py:340
# │     │  │  ├─ 0.004 wrapper  xarray/util/deprecation_helpers.py:133
# │     │  │  │  └─ 0.004 DataArray.transpose  xarray/core/dataarray.py:3122
# │     │  │  │     └─ 0.003 ItemsView.__iter__  <frozen _collections_abc>:892
# │     │  │  │        └─ 0.003 DataArrayCoordinates.__getitem__  xarray/core/coordinates.py:963
# │     │  │  │           └─ 0.003 DataArray._getitem_coord  xarray/core/dataarray.py:871
# │     │  │  │              └─ 0.002 DataArray._replace_maybe_drop_dims  xarray/core/dataarray.py:520
# │     │  │  │                 └─ 0.002 DataArray._replace  xarray/core/dataarray.py:497
# │     │  │  └─ 0.002 RasterArray.crs  rioxarray/rioxarray.py:305
# │     │  │     └─ 0.001 RasterArray._set_crs  rioxarray/rioxarray.py:397
# │     │  │        └─ 0.001 crs_from_user_input  rioxarray/crs.py:13
# │     │  ├─ 0.016 RasterArray.write_crs  rioxarray/rioxarray.py:490
# │     │  │  ├─ 0.006 CRS.to_cf  pyproj/crs/crs.py:620
# │     │  │  │  └─ 0.003 CRS.coordinate_operation  pyproj/crs/crs.py:1163
# │     │  │  ├─ 0.003 RasterArray._set_crs  rioxarray/rioxarray.py:397
# │     │  │  │  └─ 0.003 RasterArray._get_obj  rioxarray/rioxarray.py:340
# │     │  │  │     └─ 0.003 DataArray.copy  xarray/core/dataarray.py:1268
# │     │  │  │        └─ 0.003 DataArray._copy  xarray/core/dataarray.py:1338
# │     │  │  │           └─ 0.002 Variable._copy  xarray/core/variable.py:927
# │     │  │  ├─ 0.003 DataArrayCoordinates.__setitem__  xarray/core/coordinates.py:564
# │     │  │  │  └─ 0.003 DataArrayCoordinates.update  xarray/core/coordinates.py:567
# │     │  │  │     └─ 0.002 DataArrayCoordinates._update_coords  xarray/core/coordinates.py:966
# │     │  │  │        └─ 0.002 validate_dataarray_coords  xarray/core/coordinates.py:1153
# │     │  │  │           └─ 0.002 ItemsView.__iter__  <frozen _collections_abc>:892
# │     │  │  │              └─ 0.002 Coordinates.__getitem__  xarray/core/coordinates.py:458
# │     │  │  │                 └─ 0.002 Dataset.__getitem__  xarray/core/dataset.py:1327
# │     │  │  └─ 0.003 CRS.from_user_input  pyproj/crs/crs.py:477
# │     │  │     └─ 0.003 CRS.__init__  pyproj/crs/crs.py:185
# │     │  └─ 0.009 DataTree.__getitem__  xarray/core/datatree.py:922
# │     │     └─ 0.009 DataTree._get_item  xarray/core/treenode.py:538
# │     │        └─ 0.009 DataTree.get  xarray/core/datatree.py:899
# │     │           ├─ 0.007 DataTree.dataset  xarray/core/datatree.py:623
# │     │           │  └─ 0.007 DataTree._to_dataset_view  xarray/core/datatree.py:575
# │     │           │     └─ 0.004 calculate_dimensions  xarray/core/variable.py:3109
# │     │           └─ 0.002 DatasetView.__getitem__  xarray/core/datatree.py:313
# │     │              └─ 0.002 DatasetView.__getitem__  xarray/core/dataset.py:1327
# │     │                 └─ 0.002 DatasetView._construct_dataarray  xarray/core/dataset.py:1229
# │     ├─ 0.052 XarrayReader.__init__  <attrs generated methods rio_tiler.io.xarray.XarrayReader>:30
# │     │  └─ 0.052 XarrayReader.__attrs_post_init__  rio_tiler/io/xarray.py:98
# │     │     ├─ 0.026 RasterArray.bounds  rioxarray/rioxarray.py:1099
# │     │     │  ├─ 0.017 RasterArray._unordered_bounds  rioxarray/rioxarray.py:1062
# │     │     │  │  ├─ 0.014 RasterArray.resolution  rioxarray/rioxarray.py:1020
# │     │     │  │  │  └─ 0.013 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │  │  │     └─ 0.013 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │  │  │        ├─ 0.009 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │  │  │        │  ├─ 0.004 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │  │  │        │  │  └─ 0.002 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │     │  │  │        │  ├─ 0.002 isel_indexes  xarray/core/indexes.py:2112
# │     │     │  │  │        │  │  └─ 0.002 _apply_indexes_fast  xarray/core/indexes.py:2058
# │     │     │  │  │        │  └─ 0.002 DataArray._replace  xarray/core/dataarray.py:497
# │     │     │  │  │        │     └─ 0.002 DataArray.attrs  xarray/core/dataarray.py:932
# │     │     │  │  │        │        └─ 0.002 IndexVariable.attrs  xarray/namedarray/core.py:521
# │     │     │  │  │        └─ 0.002 DataArray._getitem_coord  xarray/core/dataarray.py:871
# │     │     │  │  │           └─ 0.002 DataArray._replace_maybe_drop_dims  xarray/core/dataarray.py:520
# │     │     │  │  │              └─ 0.002 DataArray._replace  xarray/core/dataarray.py:497
# │     │     │  │  └─ 0.003 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │  │     └─ 0.003 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │  │        └─ 0.002 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │  │           └─ 0.002 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │  └─ 0.009 RasterArray.resolution  rioxarray/rioxarray.py:1020
# │     │     │     └─ 0.009 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │        └─ 0.009 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │           ├─ 0.007 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │           │  └─ 0.005 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │           │     └─ 0.005 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │     │           │        └─ 0.003 apply_indexer  xarray/core/indexing.py:1152
# │     │     │           │           └─ 0.002 PandasIndexingAdapter.__getitem__  xarray/core/indexing.py:2007
# │     │     │           │              └─ 0.002 PandasIndexingAdapter._index_get  xarray/core/indexing.py:1975
# │     │     │           └─ 0.002 DataArray._getitem_coord  xarray/core/dataarray.py:871
# │     │     │              └─ 0.002 DataArray._replace_maybe_drop_dims  xarray/core/dataarray.py:520
# │     │     ├─ 0.018 RasterArray.transform  rioxarray/rioxarray.py:682
# │     │     │  ├─ 0.015 RasterArray._unordered_bounds  rioxarray/rioxarray.py:1062
# │     │     │  │  ├─ 0.009 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │  │  │  └─ 0.009 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │  │  │     ├─ 0.007 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │  │  │     │  ├─ 0.004 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │  │  │     │  │  └─ 0.002 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │     │  │  │     │  └─ 0.002 isel_indexes  xarray/core/indexes.py:2112
# │     │     │  │  │     │     └─ 0.002 _apply_indexes_fast  xarray/core/indexes.py:2058
# │     │     │  │  │     └─ 0.002 DataArray._getitem_coord  xarray/core/dataarray.py:871
# │     │     │  │  │        └─ 0.002 DataArray._replace_maybe_drop_dims  xarray/core/dataarray.py:520
# │     │     │  │  └─ 0.006 RasterArray.resolution  rioxarray/rioxarray.py:1020
# │     │     │  │     └─ 0.006 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │  │        └─ 0.006 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │  │           └─ 0.005 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │  │              └─ 0.004 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │  │                 └─ 0.004 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │     │  │                    └─ 0.003 IndexVariable._finalize_indexing_result  xarray/core/variable.py:2798
# │     │     │  │                       └─ 0.003 Variable.__init__  xarray/core/variable.py:371
# │     │     │  └─ 0.002 RasterArray.resolution  rioxarray/rioxarray.py:1020
# │     │     │     └─ 0.002 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │     │        └─ 0.002 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │     │           └─ 0.002 DataArray.isel  xarray/core/dataarray.py:1503
# │     │     │              └─ 0.002 IndexVariable.isel  xarray/core/variable.py:1093
# │     │     │                 └─ 0.002 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │     └─ 0.006 RasterArray.resolution  rioxarray/rioxarray.py:1020
# │     │        └─ 0.006 RasterArray._internal_bounds  rioxarray/rioxarray.py:1002
# │     │           └─ 0.006 DataArray.__getitem__  xarray/core/dataarray.py:882
# │     │              └─ 0.005 DataArray.isel  xarray/core/dataarray.py:1503
# │     │                 └─ 0.004 IndexVariable.isel  xarray/core/variable.py:1093
# │     │                    └─ 0.003 IndexVariable.__getitem__  xarray/core/variable.py:801
# │     │                       └─ 0.002 apply_indexer  xarray/core/indexing.py:1152
# │     │                          └─ 0.002 PandasIndexingAdapter.__getitem__  xarray/core/indexing.py:2007
# │     │                             └─ 0.002 PandasIndexingAdapter._index_get  xarray/core/indexing.py:1975
# │     └─ 0.004 XarrayReader.info  rio_tiler/io/xarray.py:179
# │        └─ 0.003 RasterArray.nodata  rioxarray/raster_array.py:355
# │           └─ 0.002 RasterArray.encoded_nodata  rioxarray/raster_array.py:345
# └─ 0.022 GeoZarrReader.__init__  <attrs generated methods titiler.eopf.reader.GeoZarrReader>:35
#    └─ 0.022 GeoZarrReader.__attrs_post_init__  titiler/eopf/reader.py:424
#       └─ 0.020 GeoZarrReader._get_groups  titiler/eopf/reader.py:474
#          ├─ 0.016 _validate_zarr  titiler/eopf/reader.py:200
#          │  └─ 0.015 RasterDataset.crs  rioxarray/raster_dataset.py:30
#          │     └─ 0.013 RasterDataset.crs  rioxarray/rioxarray.py:305
#          │        ├─ 0.009 RasterDataset.grid_mapping  rioxarray/rioxarray.py:421
#          │        │  └─ 0.007 _has_spatial_dims  rioxarray/rioxarray.py:222
#          │        │     └─ 0.007 _get_spatial_dims  rioxarray/rioxarray.py:204
#          │        │        ├─ 0.004 Dataset.__getitem__  xarray/core/dataset.py:1327
#          │        │        │  └─ 0.004 Dataset._construct_dataarray  xarray/core/dataset.py:1229
#          │        │        └─ 0.002 _CachedAccessor.__get__  xarray/core/extensions.py:21
#          │        └─ 0.003 DatasetCoordinates.__getitem__  xarray/core/coordinates.py:771
#          │           └─ 0.003 Dataset.__getitem__  xarray/core/dataset.py:1327
#          │              └─ 0.002 did_you_mean  xarray/core/utils.py:143
#          └─ 0.002 DataTree.__getitem__  xarray/core/datatree.py:922
# ```
#
#
# ## Profiling Summary (from Claude)
#
# **Total time: ~0.131s** — much faster than initialization (no S3 coordinate loading since data is already cached).
#
# ### Breakdown
#
# | Step | Time | % |
# |------|------|---|
# | `GeoZarrReader.info` → `_get_info_safe` | 0.108s | 82% |
# | Second `GeoZarrReader.__init__` (new reader instance) | 0.022s | 17% |
#
# ### `_get_info_safe` (0.108s)
#
# Split evenly between two sub-calls:
#
# **`_get_variable` (0.052s)**
# - `_arrange_dims` (0.026s): dominated by `RasterArray.write_crs` → xarray coordinate alignment/reindexing (~0.018s)
# - Second `write_crs` call (0.016s): `CRS.to_cf` + `pyproj` overhead
# - `DataTree.__getitem__` (0.009s): navigating the tree + `calculate_dimensions`
#
# **`XarrayReader.__init__` (0.052s)**
# - `RasterArray.bounds` (0.026s) and `RasterArray.transform` (0.018s) both repeatedly call `_internal_bounds` → `DataArray.__getitem__` → `IndexVariable.isel`
# - **Redundancy:** `_internal_bounds` is called ~6 times across `bounds`, `transform`, and `resolution` — all hitting the same coordinate indexing logic
#
# ### Key Observations
#
# 1. **`write_crs` called twice** in `_get_variable` — once in `_arrange_dims` and once after. The second call re-does pyproj `CRS.to_cf` which isn't cheap.
# 2. **`_internal_bounds` called repeatedly** (~6x) — `bounds`, `transform`, and `resolution` each recompute it independently rather than sharing results.
# 3. No S3 I/O — all local/cached operations, so this is pure CPU/Python overhead.

# %% [markdown]
# # Dataset Preview

# %%
profiler = Profiler()
with profiler:
    with GeoZarrReader(
        "s3://esa-zarr-sentinel-explorer-fra/tests-output/sentinel-2-l2a/S2C_MSIL2A_20260117T101351_N0511_R022_T32TQM_20260117T135312.zarr"
    ) as src:
        info = src.preview(variables=["/measurements/reflectance:b01"])

profiler.print()
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 22:35:22  Samples:  78
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 1.038     CPU time: 0.123
# /   _/                      v5.1.2
#
# Profile at /tmp/ipykernel_1374257/73601293.py:2
#
# 1.037 <module>  /tmp/ipykernel_1374257/73601293.py:1
# ├─ 0.989 GeoZarrReader.preview  titiler/eopf/reader.py:1593
# │  └─ 0.972 XarrayReader.preview  rio_tiler/io/xarray.py:486
# │        [16 frames hidden]  xarray, zarr, concurrent, threading
# │           0.957 lock.acquire  <built-in>
# └─ 0.048 GeoZarrReader.__init__  <attrs generated methods titiler.eopf.reader.GeoZarrReader>:37
#    └─ 0.048 GeoZarrReader.__attrs_post_init__  titiler/eopf/reader.py:516
#       └─ 0.039 GeoZarrReader._get_groups  titiler/eopf/reader.py:567
#          └─ 0.031 _validate_zarr  titiler/eopf/reader.py:203
#             └─ 0.028 RasterDataset.crs  rioxarray/raster_dataset.py:30
#                   [4 frames hidden]  rioxarray

# %% [markdown]
# ```
# 0.523 <module>  <ipython-input-4-2791a3b3b1c0>:1
# ├─ 0.496 GeoZarrReader.preview  titiler/eopf/reader.py:1310
# │  ├─ 0.488 XarrayReader.preview  rio_tiler/io/xarray.py:486
# │  │  └─ 0.481 DataArray.to_masked_array  xarray/core/dataarray.py:4038
# │  │     └─ 0.480 DataArray.to_numpy  xarray/core/dataarray.py:803
# │  │        └─ 0.480 Variable.to_numpy  xarray/namedarray/core.py:855
# │  │           └─ 0.480 to_numpy  xarray/namedarray/pycompat.py:99
# │  │              └─ 0.480 MemoryCachedArray.get_duck_array  xarray/core/indexing.py:942
# │  │                 └─ 0.480 CopyOnWriteArray.get_duck_array  xarray/core/indexing.py:896
# │  │                    └─ 0.480 LazilyIndexedArray.get_duck_array  xarray/core/indexing.py:733
# │  │                       └─ 0.480 ZarrArrayWrapper.__getitem__  xarray/backends/zarr.py:254
# │  │                          └─ 0.480 explicit_indexing_adapter  xarray/core/indexing.py:1101
# │  │                             └─ 0.480 ZarrArrayWrapper._getitem  xarray/backends/zarr.py:224
# │  │                                └─ 0.480 Array.__getitem__  zarr/core/array.py:2719
# │  │                                   └─ 0.479 Array.get_orthogonal_selection  zarr/core/array.py:3213
# │  │                                      └─ 0.479 sync  zarr/core/sync.py:124
# │  │                                         └─ 0.479 wait  concurrent/futures/_base.py:263
# │  │                                               [2 frames hidden]  threading
# │  │                                                  0.479 lock.acquire  <built-in>
# │  └─ 0.005 GeoZarrReader._get_variable  titiler/eopf/reader.py:839
# └─ 0.026 GeoZarrReader.__init__  <attrs generated methods titiler.eopf.reader.GeoZarrReader>:35
#    └─ 0.026 GeoZarrReader.__attrs_post_init__  titiler/eopf/reader.py:424
#       └─ 0.023 GeoZarrReader._get_groups  titiler/eopf/reader.py:474
#          └─ 0.021 _validate_zarr  titiler/eopf/reader.py:200
#             └─ 0.017 RasterDataset.crs  rioxarray/raster_dataset.py:30
#                └─ 0.016 RasterDataset.crs  rioxarray/rioxarray.py:305
#                   └─ 0.013 RasterDataset.grid_mapping  rioxarray/rioxarray.py:421
#                      └─ 0.010 _has_spatial_dims  rioxarray/rioxarray.py:222
#                         └─ 0.010 _get_spatial_dims  rioxarray/rioxarray.py:204
# ```
#
# ## Profiling Summary (from Claude)
#
# **Total time: ~0.523s**
#
# | Step | Time | % |
# |------|------|---|
# | `GeoZarrReader.preview` | 0.496s | 95% |
# | `GeoZarrReader.__init__` (new instance) | 0.026s | 5% |
#
# ### Bottleneck: actual data fetch (0.480s / 92%)
#
# `XarrayReader.preview` → `DataArray.to_masked_array` → same lazy materialization chain:
#
# ```
# MemoryCachedArray → CopyOnWriteArray → LazilyIndexedArray
#   → ZarrArrayWrapper.__getitem__
#     → zarr Array.get_orthogonal_selection
#       → sync() → lock.acquire  ← S3 pixel data read (0.479s)
# ```
#
# This is **expected** — the dominant cost is legitimate I/O fetching the preview pixels. The remaining ~0.04s of Python overhead is reasonable.
#
# ### Secondary cost: `__init__` overhead (0.026s)
#
# Same repeated pattern: `_get_groups` → `_validate_zarr` → `RasterDataset.crs` → `_get_spatial_dims` on every reader instantiation.
#
# ### Key Observations
#
# The ~0.48s is the irreducible cost of fetching real data from S3. The remaining ~0.04s is pure Python overhead (reader init, _get_variable, etc.), which is reasonable. This cell looks healthy — the dominant cost is legitimate I/O, not wasted work.
